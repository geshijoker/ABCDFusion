# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import time
import datetime
import csv
import yaml
import configparser
import copy
import math 
import random
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib
# mpl.use('Agg')
# %matplotlib inline
# %matplotlib notebook
from matplotlib import pyplot as plt 
from matplotlib.colors import ListedColormap

matplotlib.rcParams['lines.linewidth'] = 1
matplotlib.rcParams['lines.markersize'] = 5

# %% [markdown]
# # 1. Data Loading

# %%
ROOT_PATH = '../'
try: 
    os.chdir(ROOT_PATH)
    sys.path.insert(0, ROOT_PATH)
    print("Current working directory: {}".format(os.getcwd()))
except Exception:
    print("Directory: {} is not valid".format(ROOT_PATH))
    sys.exit(1)
# Out:
# Current working directory: /home/geshi/ABCDFusion

# %%
# load and parse config 
config_file = './configs.yaml'
with open(config_file, 'r') as infile:
    try:
        configs = yaml.safe_load(infile)
    except yaml.YAMLError as exc:
        sys.exit(exc)

# %%
auxiliary = configs['Auxiliary']

DATA_PATH = auxiliary['DATA_PATH']
COR_DATA = auxiliary['COR_DATA'] 
OUTCOME = auxiliary['OUTCOME']

num_splits = 5
test_size = 1/num_splits
seed = 42

# %%
df_data = pd.read_csv(os.path.join(DATA_PATH, COR_DATA), index_col=0)
df_labels = pd.read_csv(os.path.join(DATA_PATH, OUTCOME), index_col=0)

# %%
df_data.head()
# Out:
#                   CortThk_L_fronto-marginal gyrus and sulcus  \
# src_subject_id
# NDAR_INV00CY2MDM                                       2.564
# NDAR_INV00HEV6HB                                       2.360
# NDAR_INV014RTM1V                                       2.478
# NDAR_INV01AJ15N9                                       2.679
# NDAR_INV01NAYMZH                                       2.331
#
#                   CortThk_L_inferior occipital gyrus and sulcus  \
# src_subject_id
# NDAR_INV00CY2MDM                                          2.472
# NDAR_INV00HEV6HB                                          2.433
# NDAR_INV014RTM1V                                          2.477
# NDAR_INV01AJ15N9                                          2.663
# NDAR_INV01NAYMZH                                          2.734
#
#                   CortThk_L_paracentral lobule and sulcus  \
# src_subject_id
# NDAR_INV00CY2MDM                                    2.860
# NDAR_INV00HEV6HB                                    2.372
# NDAR_INV014RTM1V                                    2.456
# NDAR_INV01AJ15N9                                    2.756
# NDAR_INV01NAYMZH                                    2.852
#
#                   CortThk_L_subcentral gyrus and sulci  \
# src_subject_id
# NDAR_INV00CY2MDM                                 2.958
# NDAR_INV00HEV6HB                                 2.720
# NDAR_INV014RTM1V                                 2.587
# NDAR_INV01AJ15N9                                 2.955
# NDAR_INV01NAYMZH                                 2.805
#
#                   CortThk_L_transverse frontopolar gyri and sulci  \
# src_subject_id
# NDAR_INV00CY2MDM                                            2.828
# NDAR_INV00HEV6HB                                            2.766
# NDAR_INV014RTM1V                                            3.221
# NDAR_INV01AJ15N9                                            3.390
# NDAR_INV01NAYMZH                                            3.007
#
#                   CortThk_L_anterior part of the cingulate gyrus and sulcus  \
# src_subject_id
# NDAR_INV00CY2MDM                                              2.949
# NDAR_INV00HEV6HB                                              2.816
# NDAR_INV014RTM1V                                              2.806
# NDAR_INV01AJ15N9                                              3.159
# NDAR_INV01NAYMZH                                              3.045
#
#                   CortThk_L_middle-anterior part of the cingulate gyrus and sulcus  \
# src_subject_id
# NDAR_INV00CY2MDM                                              2.641
# NDAR_INV00HEV6HB                                              2.843
# NDAR_INV014RTM1V                                              2.769
# NDAR_INV01AJ15N9                                              3.137
# NDAR_INV01NAYMZH                                              2.877
#
#                   CortThk_L_middle-posterior part of the cingulate gyrus and sulcus  \
# src_subject_id
# NDAR_INV00CY2MDM                                              2.783
# NDAR_INV00HEV6HB                                              2.705
# NDAR_INV014RTM1V                                              2.775
# NDAR_INV01AJ15N9                                              3.010
# NDAR_INV01NAYMZH                                              2.780
#
#                   CortThk_L_posterior-dorsal part of the cingulate gyrus  \
# src_subject_id
# NDAR_INV00CY2MDM                                              2.679
# NDAR_INV00HEV6HB                                              3.094
# NDAR_INV014RTM1V                                              3.173
# NDAR_INV01AJ15N9                                              3.201
# NDAR_INV01NAYMZH                                              3.029
#
#                   CortThk_L_posterior-ventral part of the cingulate gyrus  \
# src_subject_id
# NDAR_INV00CY2MDM                                              2.935
# NDAR_INV00HEV6HB                                              2.900
# NDAR_INV014RTM1V                                              2.559
# NDAR_INV01AJ15N9                                              2.632
# NDAR_INV01NAYMZH                                              2.833
#
#                   ...  CortThk_R_parieto-occipital sulcus  \
# src_subject_id    ...
# NDAR_INV00CY2MDM  ...                               2.482
# NDAR_INV00HEV6HB  ...                               2.234
# NDAR_INV014RTM1V  ...                               2.432
# NDAR_INV01AJ15N9  ...                               2.656
# NDAR_INV01NAYMZH  ...                               2.500
#
#                   CortThk_R_pericallosal sulcus  CortThk_R_postcentral sulcus  \
# src_subject_id
# NDAR_INV00CY2MDM                          1.876                         2.445
# NDAR_INV00HEV6HB                          1.655                         2.092
# NDAR_INV014RTM1V                          1.585                         2.135
# NDAR_INV01AJ15N9                          1.842                         2.664
# NDAR_INV01NAYMZH                          1.689                         2.252
#
#                   CortThk_R_inferior part of the precentral sulcus  \
# src_subject_id
# NDAR_INV00CY2MDM                                             2.637
# NDAR_INV00HEV6HB                                             2.480
# NDAR_INV014RTM1V                                             2.676
# NDAR_INV01AJ15N9                                             2.646
# NDAR_INV01NAYMZH                                             2.481
#
#                   CortThk_R_superior part of the precentral sulcus  \
# src_subject_id
# NDAR_INV00CY2MDM                                             2.616
# NDAR_INV00HEV6HB                                             2.472
# NDAR_INV014RTM1V                                             2.632
# NDAR_INV01AJ15N9                                             2.628
# NDAR_INV01NAYMZH                                             2.465
#
#                   CortThk_R_suborbital sulcus  CortThk_R_subparietal sulcus  \
# src_subject_id
# NDAR_INV00CY2MDM                        2.406                         2.580
# NDAR_INV00HEV6HB                        3.039                         2.489
# NDAR_INV014RTM1V                        2.198                         2.617
# NDAR_INV01AJ15N9                        2.343                         2.608
# NDAR_INV01NAYMZH                        2.672                         2.474
#
#                   CortThk_R_inferior temporal sulcus  \
# src_subject_id
# NDAR_INV00CY2MDM                               2.514
# NDAR_INV00HEV6HB                               2.610
# NDAR_INV014RTM1V                               2.472
# NDAR_INV01AJ15N9                               2.558
# NDAR_INV01NAYMZH                               2.595
#
#                   CortThk_R_superior temporal sulcus  \
# src_subject_id
# NDAR_INV00CY2MDM                               2.727
# NDAR_INV00HEV6HB                               2.652
# NDAR_INV014RTM1V                               2.604
# NDAR_INV01AJ15N9                               2.711
# NDAR_INV01NAYMZH                               2.619
#
#                   CortThk_R_transverse temporal sulcus
# src_subject_id
# NDAR_INV00CY2MDM                                 2.561
# NDAR_INV00HEV6HB                                 2.277
# NDAR_INV014RTM1V                                 2.759
# NDAR_INV01AJ15N9                                 2.471
# NDAR_INV01NAYMZH                                 2.644
#
# [5 rows x 148 columns]

# %%
df_labels.head()
# Out:
#                   becomeCHR_3yr   age  sex  site
# src_subject_id
# NDAR_INV00CY2MDM              0  12.0    1    20
# NDAR_INV00HEV6HB              0  12.0    1    12
# NDAR_INV014RTM1V              0  11.0    1    17
# NDAR_INV01AJ15N9              0  12.0    1    16
# NDAR_INV01NAYMZH              0  12.0    1    16

# %%
X = df_data.iloc[:,:].values
y = df_labels.iloc[:,0].values
classes = [0, 1]

# %% [markdown]
# # 2. Machine Learning

# %% [markdown]
# ## 2.1 Define Classifiers

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import RocCurveDisplay, roc_curve, PrecisionRecallDisplay, precision_recall_curve, ConfusionMatrixDisplay, confusion_matrix, auc
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

# %%
# !export PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python

# %%
import umap

# %%
names = [
    "Nearest Neighbors",
    "Linear SVM",
    "RBF SVM",
    "Gaussian Process",
    "Decision Tree",
    "Random Forest",
    "Neural Net",
    "AdaBoost",
    "Naive Bayes",
    "QDA",
]

# %%
rng = np.random.RandomState(seed)

# %%
classifiers = [
    KNeighborsClassifier(5),
    SVC(kernel="linear", C=0.025, random_state=seed),
    SVC(gamma=2, C=1, random_state=seed),
    GaussianProcessClassifier(1.0 * RBF(1.0), random_state=seed),
    DecisionTreeClassifier(max_depth=5, random_state=seed),
    RandomForestClassifier(
        max_depth=5, n_estimators=10, max_features=1, random_state=seed
    ),
    MLPClassifier(alpha=1, max_iter=1000, random_state=seed),
    AdaBoostClassifier(random_state=seed),
    GaussianNB(),
    QuadraticDiscriminantAnalysis(),
]

# %% [markdown]
# ## 2.2 Visualize Data Distribution and Do Simple Test

# %%
reducer = umap.UMAP()
X_embedding = reducer.fit_transform(X)

X_train, X_test, y_train, y_test, Xm_train, Xm_test = train_test_split(
    X, y, X_embedding, test_size=test_size, random_state=seed
)

x_min, x_max = X_embedding[:, 0].min(), X_embedding[:, 0].max()
y_min, y_max = X_embedding[:, 1].min(), X_embedding[:, 1].max()

reducer = umap.UMAP()
# just plot the dataset first
cm = plt.cm.RdBu
cm_bright = ListedColormap(["#FF0000", "#0000FF"])

fig, ax = plt.subplots(figsize=(7, 7))
ax.set_title("Input data")    
# Plot the training points
ax.scatter(Xm_train[:, 0], Xm_train[:, 1], c=y_train, cmap=cm_bright, alpha=0.3, edgecolors="k")
# Plot the testing points
ax.scatter(
    Xm_test[:, 0], Xm_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6, edgecolors="k"
)

ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
ax.set_xticks(())
ax.set_yticks(())
plt.show()

# iterate over classifiers
for name, clf in zip(names, classifiers):
    
    print('Train classifier {}'.format(name))
    clf = make_pipeline(StandardScaler(), clf)
    # clf = make_pipeline(clf)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    
    # Calcute statistics
    precision, recall, fscore, support = score(y_test, y_pred)    

    print('| {:^6} | {:^6} | {:^6} | {:^6} | {:^6} |'.format('classes', 'precision', 'recall', 'fscore', 'support'))
    for cla, pre, rec, f1, sup in zip(classes, precision, recall, fscore, support):
        print('|  {:^6} |  {:^.3f}  |  {:^.3f}  |  {:^.3f}  |  {:^6} |'.format(cla, pre, rec, f1, sup))
        
    test_fscore = f1_score(y_test, y_pred, average='micro')
    print('micro f1 score is {:.4f}'.format(test_fscore))
    test_cfm = confusion_matrix(y_test, y_pred)
    print('confusion matrix is \n', test_cfm)
    
    # Display curves
    try:
        y_score = clf.decision_function(X_test)
        ## ROC curve
        fpr, tpr, _ = roc_curve(y_test, y_score, pos_label=clf.classes_[1])
        roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr)
        ## precision recall curve
        prec, recall, _ = precision_recall_curve(y_test, y_score, pos_label=clf.classes_[1])
        pr_display = PrecisionRecallDisplay(precision=prec, recall=recall)
        ## visualization
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 6))
        roc_display.plot(ax=ax1)
        pr_display.plot(ax=ax2)
        plt.show()
    except:
        continue
# Out:
# Train classifier Nearest Neighbors
# | classes | precision | recall | fscore | support |
# |    0    |  0.905  |  0.999  |  0.949  |   712   |
# |    1    |  0.500  |  0.013  |  0.026  |    76   |
# micro f1 score is 0.9036
# confusion matrix is
#  [[711   1]
#  [ 75   1]]
# Train classifier Linear SVM
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# | classes | precision | recall | fscore | support |
# |    0    |  0.904  |  1.000  |  0.949  |   712   |
# |    1    |  0.000  |  0.000  |  0.000  |    76   |
# micro f1 score is 0.9036
# confusion matrix is
#  [[712   0]
#  [ 76   0]]
# Train classifier RBF SVM
# | classes | precision | recall | fscore | support |
# |    0    |  0.904  |  1.000  |  0.949  |   712   |
# |    1    |  0.000  |  0.000  |  0.000  |    76   |
# micro f1 score is 0.9036
# confusion matrix is
#  [[712   0]
#  [ 76   0]]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Train classifier Gaussian Process
# | classes | precision | recall | fscore | support |
# |    0    |  0.904  |  0.954  |  0.928  |   712   |
# |    1    |  0.108  |  0.053  |  0.071  |    76   |
# micro f1 score is 0.8668
# confusion matrix is
#  [[679  33]
#  [ 72   4]]
# Train classifier Decision Tree
# | classes | precision | recall | fscore | support |
# |    0    |  0.903  |  0.992  |  0.945  |   712   |
# |    1    |  0.000  |  0.000  |  0.000  |    76   |
# micro f1 score is 0.8959
# confusion matrix is
#  [[706   6]
#  [ 76   0]]
# Train classifier Random Forest
# | classes | precision | recall | fscore | support |
# |    0    |  0.904  |  1.000  |  0.949  |   712   |
# |    1    |  0.000  |  0.000  |  0.000  |    76   |
# micro f1 score is 0.9036
# confusion matrix is
#  [[712   0]
#  [ 76   0]]
# Train classifier Neural Net
# | classes | precision | recall | fscore | support |
# |    0    |  0.902  |  0.987  |  0.943  |   712   |
# |    1    |  0.000  |  0.000  |  0.000  |    76   |
# micro f1 score is 0.8921
# confusion matrix is
#  [[703   9]
#  [ 76   0]]
# Train classifier AdaBoost
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# | classes | precision | recall | fscore | support |
# |    0    |  0.905  |  0.985  |  0.943  |   712   |
# |    1    |  0.154  |  0.026  |  0.045  |    76   |
# micro f1 score is 0.8921
# confusion matrix is
#  [[701  11]
#  [ 74   2]]
# Train classifier Naive Bayes
# | classes | precision | recall | fscore | support |
# |    0    |  0.899  |  0.701  |  0.788  |   712   |
# |    1    |  0.086  |  0.263  |  0.129  |    76   |
# micro f1 score is 0.6586
# confusion matrix is
#  [[499 213]
#  [ 56  20]]
# Train classifier QDA
# | classes | precision | recall | fscore | support |
# |    0    |  0.904  |  1.000  |  0.949  |   712   |
# |    1    |  0.000  |  0.000  |  0.000  |    76   |
# micro f1 score is 0.9036
# confusion matrix is
#  [[712   0]
#  [ 76   0]]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 2.2 Cross Validation

# %%
cv = StratifiedKFold(n_splits=num_splits)
# pick one from classifiers
classifier = classifiers[9]
clf = make_pipeline(StandardScaler(), classifier)
# classifier = svm.SVC(kernel="linear", probability=True, random_state=random_state)
# pick one from classifiers

# %%
tprs = []
aucs = []
yis = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(6, 6))
for fold, (train, test) in enumerate(cv.split(X, y)):
    clf.fit(X[train], y[train])
    
    y_score = clf.decision_function(X[test])
    fpr, tpr, thresholds =roc_curve(y[test], y_score, pos_label=clf.classes_[1])
    roc_auc = auc(fpr, tpr)
    
    i = np.arange(len(tpr))
    roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'ass' : pd.Series((tpr + (1-fpr))/2, index = i), 'thresholds' : pd.Series(thresholds, index = i)})
    yi = roc.iloc[(-roc['ass']).argsort()[:1]]
    print(yi)
    yis.append(yi['ass'].iloc[0])
    
    viz = RocCurveDisplay.from_estimator(
        clf,
        X[test],
        y[test],
        name=f"ROC fold {fold}",
        alpha=0.3,
        lw=1,
        ax=ax,
        plot_chance_level=(fold == num_splits - 1),
    )
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
mean_yi = np.mean(yis)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"Mean ROC curve with variability\n(Positive label '{classes[1]}')\n Average of sensitivity and specificity {mean_yi:.2f}",
)
ax.axis("square")
ax.legend(loc="lower right")
plt.show()
# Out:
#          fpr       tpr     1-fpr       ass  thresholds
# 21  0.108333  0.176471  0.891667  0.534069  -32.974743
#          fpr  tpr     1-fpr       ass  thresholds
# 61  0.440278  0.5  0.559722  0.529861  -57.276205
#          fpr      tpr     1-fpr       ass  thresholds
# 67  0.547222  0.58209  0.452778  0.517434  -66.392543
#          fpr       tpr     1-fpr       ass  thresholds
# 95  0.616134  0.720588  0.383866  0.552227  -69.720614
#          fpr       tpr     1-fpr       ass  thresholds
# 17  0.083449  0.132353  0.916551  0.524452  -34.594314
