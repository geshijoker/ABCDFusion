# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import time
import datetime
import csv
import yaml
import configparser
import copy
import math 
import random
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib
# mpl.use('Agg')
# %matplotlib inline
# %matplotlib notebook
from matplotlib import pyplot as plt 
from matplotlib.colors import ListedColormap

matplotlib.rcParams['lines.linewidth'] = 1
matplotlib.rcParams['lines.markersize'] = 5

# %% [markdown]
# # 1. Data Loading

# %%
ROOT_PATH = '../'
try: 
    os.chdir(ROOT_PATH)
    sys.path.insert(0, ROOT_PATH)
    print("Current working directory: {}".format(os.getcwd()))
except Exception:
    print("Directory: {} is not valid".format(ROOT_PATH))
    sys.exit(1)
# Out:
# Current working directory: /home/geshi/ABCDFusion

# %%
# load and parse config 
config_file = './configs.yaml'
with open(config_file, 'r') as infile:
    try:
        configs = yaml.safe_load(infile)
    except yaml.YAMLError as exc:
        sys.exit(exc)

# %%
auxiliary = configs['Auxiliary']
hyper_params = configs['HyperParams']

DATA_PATH = auxiliary['DATA_PATH']
CORss_DATA = auxiliary['CORss_DATA'] 
OUTCOME = auxiliary['OUTCOME']

test_size = hyper_params['valid_size']
num_splits = hyper_params['num_splits']
seed = hyper_params['seed']

# %%
df_data = pd.read_csv(os.path.join(DATA_PATH, CORss_DATA))
df_labels = pd.read_csv(os.path.join(DATA_PATH, OUTCOME))

# %%
df_data.head()
# Out:
#      src_subject_id  chg_CortThk_L_fronto-marginal gyrus and sulcus_sexsite  \
# 0  NDAR_INVR6YF8VHD                                          -0.194620
# 1  NDAR_INVKEAY17JB                                          -0.200691
# 2  NDAR_INV8YWYM3BL                                           0.094805
# 3  NDAR_INVTLE842PU                                          -0.100575
# 4  NDAR_INV6DYLLUU6                                           0.155190
#
#    chg_CortThk_L_inferior occipital gyrus and sulcus_sexsite  \
# 0                                          -0.133803
# 1                                          -0.243735
# 2                                          -0.027774
# 3                                           0.019230
# 4                                          -0.112994
#
#    chg_CortThk_L_paracentral lobule and sulcus_sexsite  \
# 0                                          -0.147310
# 1                                          -0.122860
# 2                                          -0.066100
# 3                                           0.100219
# 4                                          -0.132446
#
#    chg_CortThk_L_subcentral gyrus and sulci_sexsite  \
# 0                                         -0.072261
# 1                                         -0.187345
# 2                                         -0.036462
# 3                                         -0.066522
# 4                                         -0.113536
#
#    chg_CortThk_L_transverse frontopolar gyri and sulci_sexsite  \
# 0                                          -0.046167
# 1                                          -0.349909
# 2                                           0.083233
# 3                                          -0.141339
# 4                                          -0.042958
#
#    chg_CortThk_L_anterior part of the cingulate gyrus and sulcus_sexsite  \
# 0                                          -0.110119
# 1                                          -0.295468
# 2                                          -0.028414
# 3                                          -0.077742
# 4                                           0.070367
#
#    chg_CortThk_L_middle-anterior part of the cingulate gyrus and sulcus_sexsite  \
# 0                                          -0.088048
# 1                                          -0.155108
# 2                                          -0.203600
# 3                                          -0.147705
# 4                                           0.127523
#
#    chg_CortThk_L_middle-posterior part of the cingulate gyrus and sulcus_sexsite  \
# 0                                          -0.054431
# 1                                          -0.173851
# 2                                          -0.225456
# 3                                          -0.204947
# 4                                          -0.270084
#
#    chg_CortThk_L_posterior-dorsal part of the cingulate gyrus_sexsite  ...  \
# 0                                          -0.063655                   ...
# 1                                           0.153230                   ...
# 2                                          -0.161907                   ...
# 3                                           0.077979                   ...
# 4                                          -0.196181                   ...
#
#    chg_CortThk_R_parieto-occipital sulcus_sexsite  \
# 0                                       -0.087081
# 1                                       -0.141745
# 2                                        0.038039
# 3                                        0.129132
# 4                                       -0.187669
#
#    chg_CortThk_R_pericallosal sulcus_sexsite  \
# 0                                   0.026556
# 1                                   0.414235
# 2                                  -0.191753
# 3                                  -0.183793
# 4                                   0.008997
#
#    chg_CortThk_R_postcentral sulcus_sexsite  \
# 0                                 -0.131355
# 1                                 -0.038410
# 2                                  0.091496
# 3                                  0.034114
# 4                                 -0.099923
#
#    chg_CortThk_R_inferior part of the precentral sulcus_sexsite  \
# 0                                          -0.062504
# 1                                          -0.236020
# 2                                           0.117667
# 3                                           0.163780
# 4                                           0.109588
#
#    chg_CortThk_R_superior part of the precentral sulcus_sexsite  \
# 0                                           0.036992
# 1                                          -0.132987
# 2                                          -0.052601
# 3                                           0.160406
# 4                                          -0.098529
#
#    chg_CortThk_R_suborbital sulcus_sexsite  \
# 0                                 0.097143
# 1                                 0.140153
# 2                                -0.120077
# 3                                -0.297725
# 4                                -0.533891
#
#    chg_CortThk_R_subparietal sulcus_sexsite  \
# 0                                 -0.055251
# 1                                 -0.216815
# 2                                  0.056443
# 3                                  0.233598
# 4                                 -0.161694
#
#    chg_CortThk_R_inferior temporal sulcus_sexsite  \
# 0                                       -0.130250
# 1                                       -0.018741
# 2                                       -0.091303
# 3                                        0.094468
# 4                                       -0.152207
#
#    chg_CortThk_R_superior temporal sulcus_sexsite  \
# 0                                       -0.109177
# 1                                       -0.234259
# 2                                        0.043062
# 3                                        0.212567
# 4                                       -0.053340
#
#    chg_CortThk_R_transverse temporal sulcus_sexsite
# 0                                         -0.136679
# 1                                         -0.422616
# 2                                          0.141228
# 3                                          0.087007
# 4                                          0.082196
#
# [5 rows x 149 columns]

# %%
df_labels.head()
# Out:
#      src_subject_id  becomeCHR_3yr  diffusivity_all fibers_site  \
# 0  NDAR_INV00CY2MDM              0                     0.516813
# 1  NDAR_INV00HEV6HB              0                     0.504674
# 2  NDAR_INV014RTM1V              0                     0.499351
# 3  NDAR_INV01AJ15N9              0                     0.499413
# 4  NDAR_INV01NAYMZH              0                     0.484313
#
#    diffusivity_L_ hemisphere fibers_site  \
# 0                               0.516055
# 1                               0.503342
# 2                               0.493832
# 3                               0.497758
# 4                               0.482630
#
#    diffusivity_L_ hemisphere fibers without corpus callosum_site  \
# 0                                           0.516193
# 1                                           0.503085
# 2                                           0.500397
# 3                                           0.503652
# 4                                           0.486149
#
#    diffusivity_R_hemisphere fibers without corpus callosum_site  \
# 0                                           0.515086
# 1                                           0.507389
# 2                                           0.511758
# 3                                           0.508636
# 4                                           0.488122
#
#    diffusivity_R_hemisphere fibers_site  CortThk_L_mean_agesexsite  \
# 0                              0.516470                   2.692631
# 1                              0.504825                   2.557290
# 2                              0.501866                   2.630886
# 3                              0.501104                   2.798921
# 4                              0.484919                   2.598179
#
#    CortThk_R_mean_agesexsite  CortThkcortical Destrieux ROI mean_agesexsite
# 0                   2.718348                                       2.703962
# 1                   2.649288                                       2.664290
# 2                   2.585186                                       2.647286
# 3                   2.781255                                       2.795671
# 4                   2.620402                                       2.604037

# %%
X = df_data.iloc[:,1:].values
y = df_labels.iloc[:,1].values
classes = [0, 1]

# %% [markdown]
# # 2. Machine Learning

# %% [markdown]
# ## 2.1 Define Classifiers

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import RocCurveDisplay, roc_curve, PrecisionRecallDisplay, precision_recall_curve, ConfusionMatrixDisplay, confusion_matrix, auc
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

# %%
import umap

# %%
names = [
    "Nearest Neighbors",
    "Linear SVM",
    "RBF SVM",
    "Gaussian Process",
    "Decision Tree",
    "Random Forest",
    "Neural Net",
    "AdaBoost",
    "Naive Bayes",
    "QDA",
]

# %%
rng = np.random.RandomState(seed)

# %%
classifiers = [
    KNeighborsClassifier(5),
    SVC(kernel="linear", C=0.025, random_state=seed),
    SVC(gamma=2, C=1, random_state=seed),
    GaussianProcessClassifier(1.0 * RBF(1.0), random_state=seed),
    DecisionTreeClassifier(max_depth=5, random_state=seed),
    RandomForestClassifier(
        max_depth=5, n_estimators=10, max_features=1, random_state=seed
    ),
    MLPClassifier(alpha=1, max_iter=1000, random_state=seed),
    AdaBoostClassifier(random_state=seed),
    GaussianNB(),
    QuadraticDiscriminantAnalysis(),
]

# %% [markdown]
# ## 2.2 Visualize Data Distribution and Do Simple Test

# %%
reducer = umap.UMAP()
X_embedding = reducer.fit_transform(X)

X_train, X_test, y_train, y_test, Xm_train, Xm_test = train_test_split(
    X, y, X_embedding, test_size=test_size, random_state=seed
)

x_min, x_max = X_embedding[:, 0].min(), X_embedding[:, 0].max()
y_min, y_max = X_embedding[:, 1].min(), X_embedding[:, 1].max()

reducer = umap.UMAP()
# just plot the dataset first
cm = plt.cm.RdBu
cm_bright = ListedColormap(["#FF0000", "#0000FF"])

fig, ax = plt.subplots(figsize=(7, 7))
ax.set_title("Input data")    
# Plot the training points
ax.scatter(Xm_train[:, 0], Xm_train[:, 1], c=y_train, cmap=cm_bright, alpha=0.3, edgecolors="k")
# Plot the testing points
ax.scatter(
    Xm_test[:, 0], Xm_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6, edgecolors="k"
)

ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
ax.set_xticks(())
ax.set_yticks(())
plt.show()

# iterate over classifiers
for name, clf in zip(names, classifiers):
    
    print('Train classifier {}'.format(name))
    clf = make_pipeline(StandardScaler(), clf)
    # clf = make_pipeline(clf)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    
    # Calcute statistics
    precision, recall, fscore, support = score(y_test, y_pred)    

    print('| {:^6} | {:^6} | {:^6} | {:^6} | {:^6} |'.format('classes', 'precision', 'recall', 'fscore', 'support'))
    for cla, pre, rec, f1, sup in zip(classes, precision, recall, fscore, support):
        print('|  {:^6} |  {:^.3f}  |  {:^.3f}  |  {:^.3f}  |  {:^6} |'.format(cla, pre, rec, f1, sup))
        
    test_fscore = f1_score(y_test, y_pred, average='micro')
    print('micro f1 score is {:.4f}'.format(test_fscore))
    test_cfm = confusion_matrix(y_test, y_pred)
    print('confusion matrix is \n', test_cfm)
    
    # Display curves
    try:
        y_score = clf.decision_function(X_test)
        ## ROC curve
        fpr, tpr, _ = roc_curve(y_test, y_score, pos_label=clf.classes_[1])
        roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr)
        ## precision recall curve
        prec, recall, _ = precision_recall_curve(y_test, y_score, pos_label=clf.classes_[1])
        pr_display = PrecisionRecallDisplay(precision=prec, recall=recall)
        ## visualization
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 6))
        roc_display.plot(ax=ax1)
        pr_display.plot(ax=ax2)
        plt.show()
    except:
        continue
# Out:
# Train classifier Nearest Neighbors
# | classes | precision | recall | fscore | support |
# |    0    |  0.911  |  0.997  |  0.952  |   694   |
# |    1    |  0.333  |  0.014  |  0.028  |    69   |
# micro f1 score is 0.9083
# confusion matrix is
#  [[692   2]
#  [ 68   1]]
# Train classifier Linear SVM
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# | classes | precision | recall | fscore | support |
# |    0    |  0.910  |  1.000  |  0.953  |   694   |
# |    1    |  0.000  |  0.000  |  0.000  |    69   |
# micro f1 score is 0.9096
# confusion matrix is
#  [[694   0]
#  [ 69   0]]
# Train classifier RBF SVM
# | classes | precision | recall | fscore | support |
# |    0    |  0.910  |  1.000  |  0.953  |   694   |
# |    1    |  0.000  |  0.000  |  0.000  |    69   |
# micro f1 score is 0.9096
# confusion matrix is
#  [[694   0]
#  [ 69   0]]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Train classifier Gaussian Process
# | classes | precision | recall | fscore | support |
# |    0    |  0.911  |  0.927  |  0.919  |   694   |
# |    1    |  0.105  |  0.087  |  0.095  |    69   |
# micro f1 score is 0.8506
# confusion matrix is
#  [[643  51]
#  [ 63   6]]
# Train classifier Decision Tree
# | classes | precision | recall | fscore | support |
# |    0    |  0.909  |  0.994  |  0.950  |   694   |
# |    1    |  0.000  |  0.000  |  0.000  |    69   |
# micro f1 score is 0.9043
# confusion matrix is
#  [[690   4]
#  [ 69   0]]
# Train classifier Random Forest
# | classes | precision | recall | fscore | support |
# |    0    |  0.910  |  1.000  |  0.953  |   694   |
# |    1    |  0.000  |  0.000  |  0.000  |    69   |
# micro f1 score is 0.9096
# confusion matrix is
#  [[694   0]
#  [ 69   0]]
# Train classifier Neural Net
# | classes | precision | recall | fscore | support |
# |    0    |  0.909  |  0.994  |  0.950  |   694   |
# |    1    |  0.000  |  0.000  |  0.000  |    69   |
# micro f1 score is 0.9043
# confusion matrix is
#  [[690   4]
#  [ 69   0]]
# Train classifier AdaBoost
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# | classes | precision | recall | fscore | support |
# |    0    |  0.909  |  0.988  |  0.947  |   694   |
# |    1    |  0.000  |  0.000  |  0.000  |    69   |
# micro f1 score is 0.8991
# confusion matrix is
#  [[686   8]
#  [ 69   0]]
# Train classifier Naive Bayes
# | classes | precision | recall | fscore | support |
# |    0    |  0.908  |  0.950  |  0.928  |   694   |
# |    1    |  0.054  |  0.029  |  0.038  |    69   |
# micro f1 score is 0.8663
# confusion matrix is
#  [[659  35]
#  [ 67   2]]
# Train classifier QDA
# | classes | precision | recall | fscore | support |
# |    0    |  0.910  |  1.000  |  0.953  |   694   |
# |    1    |  0.000  |  0.000  |  0.000  |    69   |
# micro f1 score is 0.9096
# confusion matrix is
#  [[694   0]
#  [ 69   0]]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 2.2 Cross Validation

# %%
cv = StratifiedKFold(n_splits=num_splits)
# pick one from classifiers
classifier = classifiers[7]
clf = make_pipeline(StandardScaler(), classifier)
# classifier = svm.SVC(kernel="linear", probability=True, random_state=random_state)
# pick one from classifiers

# %%
tprs = []
aucs = []
yis = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(6, 6))
for fold, (train, test) in enumerate(cv.split(X, y)):
    clf.fit(X[train], y[train])
    
    y_score = clf.decision_function(X[test])
    fpr, tpr, thresholds =roc_curve(y[test], y_score, pos_label=clf.classes_[1])
    roc_auc = auc(fpr, tpr)
    
    i = np.arange(len(tpr))
    roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'ass' : pd.Series((tpr + (1-fpr))/2, index = i), 'thresholds' : pd.Series(thresholds, index = i)})
    yi = roc.iloc[(-roc['ass']).argsort()[:1]]
    print(yi)
    yis.append(yi['ass'].iloc[0])
    
    viz = RocCurveDisplay.from_estimator(
        clf,
        X[test],
        y[test],
        name=f"ROC fold {fold}",
        alpha=0.3,
        lw=1,
        ax=ax,
        plot_chance_level=(fold == num_splits - 1),
    )
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
mean_yi = np.mean(yis)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"Mean ROC curve with variability\n(Positive label '{classes[1]}')\n Average of sensitivity and specificity {mean_yi:.2f}",
)
ax.axis("square")
ax.legend(loc="lower right")
plt.show()
# Out:
#           fpr       tpr     1-fpr       ass  thresholds
# 102  0.754663  0.848485  0.245337  0.546911    -0.08892
#          fpr       tpr     1-fpr       ass  thresholds
# 91  0.677188  0.769231  0.322812  0.546021   -0.081196
#           fpr       tpr     1-fpr       ass  thresholds
# 117  0.879484  0.969231  0.120516  0.544874   -0.103741
#           fpr       tpr     1-fpr       ass  thresholds
# 120  0.837877  0.892308  0.162123  0.527216   -0.100204
#          fpr       tpr     1-fpr       ass  thresholds
# 43  0.249641  0.353846  0.750359  0.552102   -0.045838
